# %% [markdown]
# # Listing NSV content
#
# ## basic python setup

# %%
from pykg2tbl import DefaultSparqlBuilder, KGSource, QueryResult
from pathlib import Path
from pandas import DataFrame


# SPARQL EndPoint to use - wrapped as Knowledge-Graph 'source'
NSV_ENDPOINT: str = "https://vocab.nerc.ac.uk/sparql/sparql"
NSV:KGSource = KGSource.build(NSV_ENDPOINT)

TEMPLATES_FOLDER = str(Path().absolute())
GENERATOR = DefaultSparqlBuilder(templates_folder=TEMPLATES_FOLDER)


def generate_sparql(name: str, **vars) -> str: 
    """ Simply build the sparql by using the named query and applying the vars
    """
    return GENERATOR.build_syntax(name, **vars)


def execute_to_df(name: str, **vars) -> DataFrame:
    """ Builds the sparql and executes, returning the result as a dataframe.
    """
    sparql = generate_sparql(name, **vars)
    result: QueryResult = NSV.query(sparql=sparql)
    return result.to_dataframe()

# %% [markdown]
# ## finding collections
#
# The included sparql-template `./nsv-list-collections.sparql` allows for listing the collections that are available at the [NSV vocab server](https://vocab.nerc.ac.uk/)
# You can call it:
# * without any arguments to just get the full list
# * optionally with arguments `N` (limit) and `O` (offset) to paginate the result
# * optionally with argument `match` to narrow down to collections with a title matching your regex

# %%
# full list
execute_to_df("nsv-list-collections.sparql")
# Out:
#     Collection                                              Title  \
# 0          A01  International Coastal Atlas Network Coastal Er...
# 1          A02  Oregon Coastal Atlas Coastal Erosion Thesaurus...
# 2          A03  Oregon Coastal Atlas Coastal Erosion Thesaurus...
# 3          A04                     MIDA Coastal Erosion Thesaurus
# 4          A05                       AtlantOS Essential Variables
# ..         ...                                                ...
# 292        W07              SensorML Identification Section Terms
# 293        W08                     SensorML Contact Section Terms
# 294        W09  Sensor Web Enablement Observations and Measure...
# 295        W10       SensorML Output Section Data Interface Terms
# 296        W11                SensorML Event Classification Terms
#
#                                            Description
# 0    Terms used at all hierarchical levels in the I...
# 1    Terms used at all hierarchical levels in the O...
# 2    Terms used at all hierarchical levels in the O...
# 3    A collection of terms used by the Irish Marine...
# 4    Collection of terms used to group key measurem...
# ..                                                 ...
# 292  Terms used in SensorML to identify an observat...
# 293  Terms used in SensorML to describe the role an...
# 294  Terms used in SWE Observations and Measurement...
# 295  Terms used in SensorML to describe the softwar...
# 296  Terms used in SensorML to describe aspects of ...
#
# [297 rows x 3 columns]

# %%
# page 3 of size 20
size = 20
count = 3
execute_to_df("nsv-list-collections.sparql", N=size, O=(count -1)*size)
# Out:
#    Collection                                              Title  \
# 0         C41                      BODC marine pollution sources
# 1         C43                             BODC oilspill quantity
# 2         C45  Marine Strategy Framework Directive descriptor...
# 3         C46  Marine Strategy Framework Directive criteria 2...
# 4         C47  Marine Strategy Framework Directive indicators...
# 5         C48                              MEDIN Data Guidelines
# 6         C59  BODC organisation roles within activities and ...
# 7         C60        NERC DataGrid vocabulary term relationships
# 8         C61                               BODC post town names
# 9         C62                   BODC administrative region names
# 10        C64     United Kingdom Charting Progress 2 sea regions
# 11        C67             BODC series parameter collection names
# 12        C71                       BODC organisation categories
# 13        C72                            BODC core failure codes
# 14        C75                        BODC Organisation Histories
# 15        C77   SeaDataNet Cruise Summary Report data categories
# 16        C86       SeaDataNet contact and security access roles
# 17        C87                                 BODC project roles
# 18        C88                      BODC asset access right roles
# 19        C89                                 BODC dataset roles
#
#                                           Description
# 0   Terms developed by BODC to provide a standard ...
# 1   Terms developed by BODC to classify the magnit...
# 2   Concepts specified as descriptors of good envi...
# 3   Concepts specified as criteria to be used to m...
# 4   Concepts specified as indicators to be used to...
# 5   Documents produced by the Marine Environmental...
# 6   Generic terms used by BODC to describe the rel...
# 7   Terms used in the NDG project to describe the ...
# 8   Labels used by BODC to populate 'city' or 'pos...
# 9   Labels used by BODC to populate 'county' metad...
# 10  Terms used specify regions of the seas around ...
# 11  Terms used by BODC to describe groups of relat...
# 12  Terms used by BODC to classify the organisatio...
# 13  Concepts that describe sediment corer deployme...
# 14  Concepts used to populate 'organisation' field...
# 15  Terms used to describe shipboard activities (s...
# 16  SeaDataNet terms to describe roles associated ...
# 17  Terms used by BODC to describe roles associate...
# 18  Terms used by BODC to describe roles specifyin...
# 19  Terms used by BODC for roles that describe the...

# %%
#matching for "platform"
term="platform"
execute_to_df("nsv-list-collections.sparql", regex=term)
# Out:
#   Collection                                              Title  \
# 0        B76                               BODC Platform Models
# 1        C17                                ICES Platform Codes
# 2        EL1  SeaVoX Sampling and Observation Platform Event...
# 3        EL2  SeaVoX Sampling and Observation Platform Event...
# 4        L06                         SeaVoX Platform Categories
# 5        P19           Global Change Master Directory platforms
# 6        R22                               Argo platform family
# 7        R23                                 Argo platform type
# 8        R24                                Argo platform maker
#
#                                          Description
# 0  Terms used to describe designs or versions of ...
# 1  Identifiers and metadata for platform instance...
# 2  Terms used to identify actions performed on sa...
# 3  Terms used to identify processes performed on ...
# 4  2-level grouping term hierarchy used for vehic...
# 5  Terms used to describe sensor-bearing platform...
# 6  List of platform family/category of Argo float...
# 7  List of Argo float types. Argo netCDF variable...
# 8  List of Argo float manufacturers. Argo netCDF ...

# %% [markdown]
# ## listing terms in selected collections
#
# The included sparql-template `./nsv-listing.sparql` allows for listing the terms in a selected collection at the [NSV vocab server](https://vocab.nerc.ac.uk/)
# You can call it:
# * with at least the `cc` argument indicating the code of the selected collection you want to list
# * optionally with arguments `N` (limit) and `O` (offset) to paginate the result
# * optionally with argument `lang` to get term labels in another language (defaults to 'en')

# %%
execute_to_df("nsv-listing.sparql", cc="P06")
# Out:
#         IDENTIFIER                  PreferedLabelTranslated AlternateLabel  \
# 0    SDN:P06::BQSM              Becquerels per square metre         Bq/m^2
# 1    SDN:P06::BSM3        Becquerels second per cubic metre       Bq.s/m^3
# 2    SDN:P06::KMP2               Kilograms per square metre         kg/m^2
# 3    SDN:P06::UKMC                Kilograms per cubic metre         kg/m^3
# 4    SDN:P06::UUUU                            Dimensionless        Dmnless
# ..             ...                                      ...            ...
# 391  SDN:P06::UMIN                                  Minutes            min
# 392  SDN:P06::SQCC  Square centimetres per cubic centimetre      cm^2/cm^3
# 393  SDN:P06::MGAL                                MilliGals           mGal
# 394  SDN:P06::UNDX          Number per square metre per day        #/m^2/d
# 395  SDN:P06::PMLD              Picomoles per litre per day       pmol/l/d
#
#     IsDeprecated                                         ConceptIRI  \
# 0          false  http://vocab.nerc.ac.uk/collection/P06/current...
# 1          false  http://vocab.nerc.ac.uk/collection/P06/current...
# 2          false  http://vocab.nerc.ac.uk/collection/P06/current...
# 3          false  http://vocab.nerc.ac.uk/collection/P06/current...
# 4          false  http://vocab.nerc.ac.uk/collection/P06/current...
# ..           ...                                                ...
# 391        false  http://vocab.nerc.ac.uk/collection/P06/current...
# 392        false  http://vocab.nerc.ac.uk/collection/P06/current...
# 393        false  http://vocab.nerc.ac.uk/collection/P06/current...
# 394        false  http://vocab.nerc.ac.uk/collection/P06/current...
# 395        false  http://vocab.nerc.ac.uk/collection/P06/current...
#
#     AlternateLabelTranslated
# 0                        NaN
# 1                        NaN
# 2                     kg/m^2
# 3                     kg/m^3
# 4                    Dmnless
# ..                       ...
# 391                      NaN
# 392                      NaN
# 393                      NaN
# 394                      NaN
# 395                      NaN
#
# [396 rows x 6 columns]

# %% [markdown]
# ## Searching for mathcing terms accross collections
#
# The included sparql-template `./nsv-find.sparql` allows for finding a matching concept in a collection from the [NSV vocab server](https://vocab.nerc.ac.uk/)
# You can call it:
# * with at least the `collections` argument indicating a list of collections you want to search in - if '*' is passed the search goes across
# * optionally with argument `lang` to get term labels in another language (defaults to 'en')
# * optionally with argument `regex` to pass the regex that should match the prefLabel of the Concept

# %%
term="id.* specified elsewhere"
execute_to_df("nsv-find.sparql", regex=term, collections=['P01'])
# Out:
#                                           ConceptIRI         Identifier  \
# 0  http://vocab.nerc.ac.uk/collection/P01/current...  SDN:P01::CAPWID01
# 1  http://vocab.nerc.ac.uk/collection/P01/current...  SDN:P01::LIDYXX01
# 2  http://vocab.nerc.ac.uk/collection/P01/current...  SDN:P01::LIWTXX01
# 3  http://vocab.nerc.ac.uk/collection/P01/current...  SDN:P01::NCOLIVXX
# 4  http://vocab.nerc.ac.uk/collection/P01/current...  SDN:P01::SNANID01
# 5  http://vocab.nerc.ac.uk/collection/P01/current...  SDN:P01::SOVO0004
# 6  http://vocab.nerc.ac.uk/collection/P01/current...  SDN:P01::WDPIXEL1
#
#                              PreferedLabelTranslated
# 0  Width of biological entity specified elsewhere...
# 1  Concentration of lipids per unit dry weight of...
# 2  Concentration of lipids per unit wet weight of...
# 3  Count of colonial individuals per colony of bi...
# 4  Identifier (LSID) of biological entity specifi...
# 5  Count (January) {midwinter count} of biologica...
# 6  Width (expressed as pixels) of biological enti...

# %% [markdown]
# ## Collect some details on a known list of terms (identified by URI)
#
# The included sparql template `nsv-get-details.sparql` allows for listing some extra information on specific terms from NVS one has the identifying URI for. You can need to call:
# * with a non-empty list of `uris` that match the concept identifiers you are looking up
# * optionally with argument `lang` to get term labels in another language (defaults to 'en')

# %%
uris = ['http://vocab.nerc.ac.uk/collection/L05/current/180/',
        'http://vocab.nerc.ac.uk/collection/L05/current/181/',
        'http://vocab.nerc.ac.uk/collection/L05/current/22/']
execute_to_df("nsv-get-details.sparql", uris=uris)
#print(generate_sparql("nsv-get-details.sparql", uris=uris))
# Out:
#                                           ConceptIRI    Identifier  \
# 0  http://vocab.nerc.ac.uk/collection/L05/current...  SDN:L05::180
# 1  http://vocab.nerc.ac.uk/collection/L05/current...  SDN:L05::181
# 2  http://vocab.nerc.ac.uk/collection/L05/current...   SDN:L05::22
#
#   PreferedLabelTranslated isDeprecated
# 0      underwater cameras         true
# 1      nutrient analysers        false
# 2           plankton nets        false
